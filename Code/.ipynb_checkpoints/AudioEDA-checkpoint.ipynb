# %%
# !pip install librosa matplotlib pandas numpy
# Out:
# Collecting librosa
#   Downloading librosa-0.10.2.post1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: matplotlib in /home/momo/miniconda3/lib/python3.12/site-packages (3.10.0)
# Requirement already satisfied: pandas in /home/momo/miniconda3/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy in /home/momo/miniconda3/lib/python3.12/site-packages (1.26.4)
# Collecting audioread>=2.1.9 (from librosa)
#   Downloading audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: scipy>=1.2.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from librosa) (1.15.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /home/momo/miniconda3/lib/python3.12/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from librosa) (5.1.1)
# Collecting numba>=0.51.0 (from librosa)
#   Downloading numba-0.61.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting soundfile>=0.12.1 (from librosa)
#   Downloading soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (16 kB)
# Collecting pooch>=1.1 (from librosa)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Downloading soxr-0.5.0.post1-cp312-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/momo/miniconda3/lib/python3.12/site-packages (from librosa) (4.12.2)
# Collecting lazy-loader>=0.1 (from librosa)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting msgpack>=1.0 (from librosa)
#   Downloading msgpack-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/momo/miniconda3/lib/python3.12/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/momo/miniconda3/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/momo/miniconda3/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/momo/miniconda3/lib/python3.12/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/momo/miniconda3/lib/python3.12/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/momo/miniconda3/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/momo/miniconda3/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/momo/miniconda3/lib/python3.12/site-packages (from pandas) (2025.1)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba>=0.51.0->librosa)
#   Downloading llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from pooch>=1.1->librosa) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: six>=1.5 in /home/momo/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in /home/momo/miniconda3/lib/python3.12/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/momo/miniconda3/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/momo/miniconda3/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/momo/miniconda3/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/momo/miniconda3/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.1.31)
# Downloading librosa-0.10.2.post1-py3-none-any.whl (260 kB)
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading msgpack-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (401 kB)
# Downloading numba-0.61.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 9.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
# Downloading soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.5 MB/s eta 0:00:00
# Downloading soxr-0.5.0.post1-cp312-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (248 kB)
# Downloading llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 14.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Installing collected packages: soxr, msgpack, llvmlite, lazy-loader, audioread, soundfile, pooch, numba, librosa
# Successfully installed audioread-3.0.1 lazy-loader-0.4 librosa-0.10.2.post1 llvmlite-0.44.0 msgpack-1.1.0 numba-0.61.0 pooch-1.8.2 soundfile-0.13.1 soxr-0.5.0.post1

# %%
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import Audio, display

# %%
# Define paths
train_path = "/home/momo/Documents/Datasets/Audio/train"
test_path = "/home/momo/Documents/Datasets/Audio/test"

# Load metadata
train_csv = os.path.join(train_path, "train.csv")
if os.path.exists(train_csv):
    train_df = pd.read_csv(train_csv)
else:
    train_df = None

# %%
# function to load and visualize an audio file
def visualize_audio(file_path):
    y, sr = librosa.load(file_path, sr=None)
    plt.figure(figsize=(10, 4))
    librosa.display.waveshow(y, sr=sr)
    plt.title("Waveform")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")
    plt.show()
    
    plt.figure(figsize=(10, 4))
    D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
    librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='log')
    plt.colorbar(format='%+2.0f dB')
    plt.title("Spectrogram")
    plt.show()
    
    display(Audio(file_path))

# get audio file distribution
def get_class_distribution(df):
    if df is not None:
        plt.figure(figsize=(12, 6))
        df["label"].value_counts().plot(kind='bar')
        plt.xlabel("Class")
        plt.ylabel("Count")
        plt.title("Distribution of Audio Classes in Train Set")
        plt.xticks(rotation=90)
        plt.show()

# %%
# function to compute basic statistics
def compute_audio_statistics(audio_dir):
    durations = []
    for file in os.listdir(audio_dir):
        if file.endswith(".wav"):
            file_path = os.path.join(audio_dir, file)
            y, sr = librosa.load(file_path, sr=None)
            durations.append(librosa.get_duration(y=y, sr=sr))
    
    if durations:
        print(f"Total files analyzed: {len(durations)}")
        print(f"Mean duration: {np.mean(durations):.2f} sec")
        print(f"Max duration: {np.max(durations):.2f} sec")
        print(f"Min duration: {np.min(durations):.2f} sec")
        
        plt.figure(figsize=(10, 5))
        plt.hist(durations, bins=30, edgecolor='black')
        plt.xlabel("Duration (seconds)")
        plt.ylabel("Frequency")
        plt.title("Audio File Duration Distribution")
        plt.show()
    else:
        print("No audio files found in the directory.")

# run EDA
if os.path.exists(train_path):
    print("Train Dataset Analysis")
    if train_df is not None:
        get_class_distribution(train_df)
    compute_audio_statistics(train_path)
    sample_audio = np.random.choice([f for f in os.listdir(train_path) if f.endswith(".wav")])
    visualize_audio(os.path.join(train_path, sample_audio))

if os.path.exists(test_path):
    print("Test Dataset Analysis")
    compute_audio_statistics(test_path)
# Out:
# Train Dataset Analysis
# Total files analyzed: 9473
# Mean duration: 6.79 sec
# Max duration: 30.00 sec
# Min duration: 0.30 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Test Dataset Analysis
# Total files analyzed: 1600
# Mean duration: 5.20 sec
# Max duration: 29.74 sec
# Min duration: 0.30 sec

# %%
# !pip install librosa matplotlib pandas numpy torch torchvision torchaudio
# Out:
# Requirement already satisfied: librosa in /home/momo/miniconda3/lib/python3.12/site-packages (0.10.2.post1)
# Requirement already satisfied: matplotlib in /home/momo/miniconda3/lib/python3.12/site-packages (3.10.0)
# Requirement already satisfied: pandas in /home/momo/miniconda3/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy in /home/momo/miniconda3/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: torch in /home/momo/miniconda3/lib/python3.12/site-packages (2.4.0)
# Requirement already satisfied: torchvision in /home/momo/miniconda3/lib/python3.12/site-packages (0.19.0)
# Requirement already satisfied: torchaudio in /home/momo/miniconda3/lib/python3.12/site-packages (2.4.0)
# Requirement already satisfied: audioread>=2.1.9 in /home/momo/miniconda3/lib/python3.12/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from librosa) (1.15.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /home/momo/miniconda3/lib/python3.12/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from librosa) (0.61.0)
# Requirement already satisfied: soundfile>=0.12.1 in /home/momo/miniconda3/lib/python3.12/site-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /home/momo/miniconda3/lib/python3.12/site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /home/momo/miniconda3/lib/python3.12/site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/momo/miniconda3/lib/python3.12/site-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /home/momo/miniconda3/lib/python3.12/site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from librosa) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/momo/miniconda3/lib/python3.12/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/momo/miniconda3/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/momo/miniconda3/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/momo/miniconda3/lib/python3.12/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/momo/miniconda3/lib/python3.12/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/momo/miniconda3/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/momo/miniconda3/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/momo/miniconda3/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: filelock in /home/momo/miniconda3/lib/python3.12/site-packages (from torch) (3.13.1)
# Requirement already satisfied: sympy in /home/momo/miniconda3/lib/python3.12/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /home/momo/miniconda3/lib/python3.12/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/momo/miniconda3/lib/python3.12/site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /home/momo/miniconda3/lib/python3.12/site-packages (from torch) (2024.12.0)
# Requirement already satisfied: setuptools in /home/momo/miniconda3/lib/python3.12/site-packages (from torch) (75.8.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /home/momo/miniconda3/lib/python3.12/site-packages (from numba>=0.51.0->librosa) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from pooch>=1.1->librosa) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: six>=1.5 in /home/momo/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/momo/miniconda3/lib/python3.12/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: pycparser in /home/momo/miniconda3/lib/python3.12/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/momo/miniconda3/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/momo/miniconda3/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/momo/miniconda3/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/momo/miniconda3/lib/python3.12/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.1.31)

# %%
# Function to apply JointMatch
def apply_jointmatch(train_data, test_data):
    print("Applying JointMatch on the dataset...")
    # Placeholder for JointMatch implementation
    pass

# Function to apply EPASS
def apply_epass(train_data, test_data):
    print("Applying EPASS on the dataset...")
    # Placeholder for EPASS implementation
    pass

# Function to compare results
def compare_results(jointmatch_results, epass_results):
    print("Comparing JointMatch and EPASS results...")
    # Placeholder for comparison metrics like accuracy, loss, etc.
    pass


# Execute JointMatch and EPASS
jointmatch_results = apply_jointmatch(train_path, test_path)
epass_results = apply_epass(train_path, test_path)
compare_results(jointmatch_results, epass_results)
# Out:
# Applying JointMatch on the dataset...
# Applying EPASS on the dataset...
# Comparing JointMatch and EPASS results...
